# %% [markdown]
# <a href="https://colab.research.google.com/github/wuuluu/-/blob/main/beiji.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 第一步：安装必要的环境库
# 在第一个代码块中输入并运行以下命令。这会安装 Google 官方的 Generative AI Python SDK。

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# 第二步：配置安全密钥与初始化最新模型
# 在 Colab 左侧的钥匙图标 (🔑) 中，新建一个机密，命名为 beiji，并将你的 API 密钥填入，开启 "Notebook access"。然后在第二个代码块运行：

# %%
import google.generativeai as genai
from google.colab import userdata
import json

# 1. 安全调用名为 'beiji' 的密钥
try:
    GOOGLE_API_KEY = userdata.get('beiji')
    genai.configure(api_key=GOOGLE_API_KEY)
    print("密钥加载成功，环境配置完成。")
except Exception as e:
    print(f"密钥加载失败，请检查 Colab 左侧的机密设置是否正确命名为 'beiji'。错误信息: {e}")

# 2. 选取最新的 Pro 模型
# 使用 'gemini-1.5-pro-latest' 确保调用的是该系列最新发布的迭代版本，
# 这比基础的 flash 模型在处理复杂因果关系抽取时更精准。
model = genai.GenerativeModel('gemini-1.5-pro-latest')
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# 密钥加载成功，环境配置完成。
